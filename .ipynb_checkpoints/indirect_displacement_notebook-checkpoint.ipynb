# %%
from census import Census
import numpy as np
import pandas as pd

import geopandas as gpd

import cenpy as cen

from us import states

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load PLUTO Data

# %%
filename = 'pluto_census_tract.geojson'
pluto = gpd.read_file(filename)

# %%
pluto.head()
# Out:
#              address         bbl cb2010 ct2010  \
# 0    668 CARY AVENUE  5002230055   1004    125
# 1    666 CARY AVENUE  5002230057   1004    125
# 2    656 CARY AVENUE  5002230060   1004    125
# 3      TAYLOR STREET  5002230078   1004    125
# 4  296 TAYLOR STREET  5002230080   1004    125
#
#                                             geometry
# 0  (POLYGON ((-74.12380400000001 40.63145, -74.12...
# 1  (POLYGON ((-74.123716 40.631469, -74.123804000...
# 2  (POLYGON ((-74.12279599999999 40.631304, -74.1...
# 3  (POLYGON ((-74.12278499999999 40.631222, -74.1...
# 4  (POLYGON ((-74.122761 40.631034, -74.123231 40...

# %%
print(len(set(pluto['ct2010'])))
len((set(pluto['cb2010'])))
# Out:
# 1336
# 369

# %% [markdown]
# # Get Tract Income and Population from Census 2010

# %%
c = Census("13c056d339e329f0a4fbef4384e3667e505a55da")
c.acs5.tables()
# Out:
# [{'name': 'B07012',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY POVERTY STATUS IN THE PAST 12 MONTHS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B07012.json'},
#  {'name': 'B07013',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY TENURE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B07013.json'},
#  {'name': 'B13002A',
#   'description': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B13002A.json'},
#  {'name': 'B13002C',
#   'description': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B13002C.json'},
#  {'name': 'B13002B',
# ...

# %%
pop = pd.DataFrame(c.acs5.get('B01003_001E', geo={'for': 'tract:*',
                       'in': 'state:{}'.format(states.NY.fips)}))
pop
# Out:
#       B01003_001E county state   tract
# 0          1565.0    081    36  011900
# 1          1607.0    081    36  013500
# 2          1981.0    081    36  013600
# 3          1822.0    081    36  014100
# 4          2267.0    081    36  014500
# 5          2482.0    081    36  016100
# 6          3558.0    081    36  016300
# 7          1457.0    081    36  018000
# 8          1974.0    081    36  020600
# 9          4380.0    081    36  006900
# 10         5823.0    081    36  023200
# 11         2889.0    081    36  012601
# 12         2456.0    081    36  013200
# 13         4252.0    081    36  007500
# 14         1153.0    081    36  026200
# 15         4338.0    081    36  059300
# 16         1693.0    081    36  059800
# 17         1188.0    081    36  060000
# 18         2376.0    081    36  061601
# 19         1439.0    081    36  062000
# 20         2807.0    081    36  062500
# 21         2609.0    081    36  063500
# 22         5816.0    081    36  065600
# ...

# %%
income = pd.DataFrame(c.acs5.get('B19013_001E', geo={'for': 'tract:*',
                       'in': 'state:{}'.format(states.NY.fips)}))
income
# Out:
#       B19013_001E county state   tract
# 0         63750.0    081    36  011900
# 1         67132.0    081    36  013500
# 2         66645.0    081    36  013600
# 3         61154.0    081    36  014100
# 4         65313.0    081    36  014500
# 5         51964.0    081    36  016100
# 6         20920.0    081    36  016300
# 7         66739.0    081    36  018000
# 8         69630.0    081    36  020600
# 9         58879.0    081    36  006900
# 10        70729.0    081    36  023200
# 11        70179.0    081    36  012601
# 12        66250.0    081    36  013200
# 13        81716.0    081    36  007500
# 14        71250.0    081    36  026200
# 15        60258.0    081    36  059300
# 16        86506.0    081    36  059800
# 17        81731.0    081    36  060000
# 18        97500.0    081    36  061601
# 19       106500.0    081    36  062000
# 20        76250.0    081    36  062500
# 21        54865.0    081    36  063500
# 22        78314.0    081    36  065600
# ...

# %% [markdown]
# # Address to tract income and population

# %%
def reformat_pluto_tract_num(tract):
    tract = tract.replace(".", "")
    while len(tract) < 6:
        tract = '0' + tract
    return tract

# %%
def generate_report(building_profile):
    building_tract = reformat_pluto_tract_num(pluto[pluto['address'] == building_profile['address']]['ct2010'].values[0])
#     print(f"Build Census Tract: {building_tract}")
    tract_income = float(income[income['tract'] == building_tract]['B19013_001E'])
    print(f"Building Census Tract Income: {tract_income}")
    tract_population = float(pop[pop['tract'] == building_tract]['B01003_001E'])
    print(f"Building Census Tract Population: {tract_population}")
    print("\n")
    
    income_similarity = 5000
    
    # Step 1 Logic
    if (building_profile['expected_income'] < tract_income + income_similarity) and (building_profile['expected_income'] > tract_income - income_similarity):
        print("Step 1: No further analysis needed")
    else:
        print("Step 1: Expecterd average incomes of new population is not similar to average income of the study area populations. Further analysis is required")
        population_increase = (building_profile['num_residence'] + tract_population) / tract_population
#         print(population_increase)
        print("\n")
        # Step 2 Logic
        if population_increase < 1.05:
            print("Step 2: No further analysis required")
        else:
            print("Step 2: Population increase in greater than 5%. Futher analysis is required.")

# %%
# Define Building Profile
building_profile = {"num_residence": 1000, "expected_income": 120000, "address": '1 EAST LOOP ROAD'}

# %%
generate_report(building_profile)
# Out:
# Building Census Tract Income: 88724.0
# Building Census Tract Population: 9300.0
#
#
# Step 1: Expecterd average incomes of new population is not similar to average income of the study area populations. Further analysis is required
#
#
# Step 2: Population increase in greater than 5%. Futher analysis is required.

# %%
# function to find address in neighboorhood shape file 
# get neighboorhood, return zillow states
# https://automating-gis-processes.github.io/CSC18/lessons/L4/point-in-polygon.html

# %% [markdown]
# # Zillow Data

# %%
from shapely.geometry import Point, Polygon
from geopy.geocoders import Nominatim

# %%
zillow_data = pd.read_csv('Neighborhood_Zhvi_AllHomes.csv')
zillow_data = zillow_data[zillow_data['City'] == 'New York']
print(len(set(zillow_data['RegionName'])))
len(zillow_data['RegionName'])
zillow_data['RegionName']
# Out:
# 194
# 2                           Upper West Side
# 4                           Upper East Side
# 8                             East New York
# 10                       Washington Heights
# 13                                  Astoria
# 15                       Bedford Stuyvesant
# 16                             Williamsburg
# 20                                 Flatbush
# 23                            Crown Heights
# 24                                  Jamaica
# 26                           Williamsbridge
# 27                              East Harlem
# 32                                 Bushwick
# 33                            East Flatbush
# 36                                   Corona
# 38                              Sunset Park
# 41                             Borough Park
# 42                              Bensonhurst
# 46                                 Elmhurst
# 53                           Sheepshead Bay
# 54                              South Bronx
# ...

# %%
zillow_shape_file = gpd.read_file('ZillowNeighborhoods-NY/ZillowNeighborhoods-NY.shp')
zillow_shape_file = zillow_shape_file[zillow_shape_file['City'] == 'New York']
zillow_shape_file.head()
# Out:
#    State    County      City              Name RegionID  \
# 2     NY    Queens  New York         Rego Park     6719
# 5     NY    Queens  New York      Belle Harbor    10329
# 10    NY  New York  New York  Roosevelt Island    20239
# 13    NY    Queens  New York      Howard Beach    21970
# 16    NY    Queens  New York      Breezy Point    37557
#
#                                              geometry
# 2   POLYGON ((-73.85629999999999 40.72303000000012...
# 5   POLYGON ((-73.85618223699993 40.56810940300005...
# 10  POLYGON ((-73.96143117599991 40.74851331600007...
# 13  POLYGON ((-73.85608525799972 40.65037135900031...
# 16  POLYGON ((-73.90962826099991 40.56552556300005...

# %%
def address_to_neighborhood(addr):
    """Returns a zillow neighborhood given an address"""
    geolocator = Nominatim(user_agent="collate")
    location = geolocator.geocode(addr)
    location = Point(location.longitude, location.latitude)
    
    for i, row in zillow_shape_file.iterrows():
        polygon = row.get('geometry')
        if location.within(polygon):
            return row.get('Name')
        
def address_realestate_features(addr, years=2):
    neighborhood = address_to_neighborhood(addr)
    features = zillow_data[zillow_data['RegionName'] == neighborhood]
    return features.iloc[:,-12 * years :]
    

def plot_realestate_trends(addr, years=2):
    features = address_realestate_features(addr, years)
    x = list(features)
    addr_y = features.values.reshape(len(x))
    
    city_average = zillow_data[zillow_data.columns[-years * 12:]].mean(axis=0)
    
    plt.xticks(rotation=90)
    plt.plot(x, addr_y)
    plt.plot(x, city_average)

# %%
plot_realestate_trends("1 East Loop Rd.", years=10)
# Do we have to control for inflation / natural growth of real estate prices? Compare to city average?

# %%
c = Census("13c056d339e329f0a4fbef4384e3667e505a55da")
pop = c.sf1.get('P001001', {'for': 'state:*'})
c.sf1.tables()

# %%
NY_tract_pop = c.sf1.get('P001001', geo={'for': 'tract:*',
                       'in': 'state:{}'.format(states.NY.fips)})

# %%
NY_tract_pop = pd.DataFrame(NY_tract_pop)

# %%
NY_tract_pop = c.sf1.get('P001001', geo={'for': 'tract:*',
                       'in': 'state:{}'.format(states.NY.fips)})

# %%
c.sf1.get('P001001', geo={'for': states.AK.fips})

# %%
datasets = list(cen.explorer.available(verbose=True).items())

# print first rows of the dataframe containing datasets
pd.DataFrame(datasets)

dataset = '2012acs1'
cen.explorer.explain(dataset)

con = cen.base.Connection(dataset)

# %%
var = con.variables
print('Number of variables in', dataset, ':', len(var))
con.variables.head()

# %%
g_unit = 'county:*'
g_filter = {'state':'8'}

cols = con.varslike('B01003')
cols.extend(['NAME', 'GEOID','TRACT'])

data = con.query(cols, geo_unit=g_unit, geo_filter=g_filter)

# %%
data
